# %% [markdown]
# <a href="https://colab.research.google.com/github/Jeongyoon-Jang/SOLUX_image-data-analysis/blob/main/Image_augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import os
import cv2
from os import listdir
from os.path import isfile, join
from PIL import Image

np.random.seed(3)
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
 

data_datagenator = ImageDataGenerator(rescale=1./255,
                                   rotation_range=30, 
                                   shear_range=5.5,  
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   zoom_range=0.,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='nearest') 
 
filename_in_dir = [] 
 
for root, dirs, files in os.walk('/content/drive/MyDrive/SOLUX_21-1_DIVA/images_최종/training_set/safe_place/안심골목길조성'):
    for  fname in files:
        full_fname = os.path.join(root, fname)
        filename_in_dir.append(full_fname)


for file_image in filename_in_dir:
    print(file_image)
    img = cv2.cvtColor(cv2.imread(file_image), cv2.COLOR_BGR2RGB)
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)
 
    i = 0
    for batch in data_datagenator.flow(x,save_to_dir='/content/drive/MyDrive/SOLUX_21-1_DIVA/images_최종/training_set/safe_place/안심골목길조성', save_prefix='safe_place_안심골목길조성', save_format='jpg'):
        i += 1
        if i > 3:
            break
# Out:
# /content/drive/MyDrive/SOLUX_21-1_DIVA/images_최종/training_set/safe_place/안심골목길조성/안심골목길조성108.jpg
# /content/drive/MyDrive/SOLUX_21-1_DIVA/images_최종/training_set/safe_place/안심골목길조성/안심골목길조성107.jpg
# /content/drive/MyDrive/SOLUX_21-1_DIVA/images_최종/training_set/safe_place/안심골목길조성/안심골목길조성109.jpg
# /content/drive/MyDrive/SOLUX_21-1_DIVA/images_최종/training_set/safe_place/안심골목길조성/안심골목길조성1.jpg
# /content/drive/MyDrive/SOLUX_21-1_DIVA/images_최종/training_set/safe_place/안심골목길조성/안심골목길조성2.jpg
# /content/drive/MyDrive/SOLUX_21-1_DIVA/images_최종/training_set/safe_place/안심골목길조성/안심골목길조성3.jpg
# /content/drive/MyDrive/SOLUX_21-1_DIVA/images_최종/training_set/safe_place/안심골목길조성/안심골목길조성4.jpg
# ...
